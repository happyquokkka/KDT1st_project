# %%
import geopandas as gpd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable
from shapely.geometry import Point

# %%
# 시도경계 shapefile
shapefile = 'C:\DataScience\project\geo_data\gadm36_KOR_1.shp'
gdf = gpd.read_file(shapefile)[['NAME_1', 'geometry']]
gdf.columns = ['name','geometry']
gdf["center"] = gdf["geometry"].centroid
gdf_points = gdf.copy()
gdf_points['city']=['부산', '충북','충남','대구','대전','강원','광주','경기','경북',
                    '경남','인천','제주','전북','전남','세종','서울','울산']
gdf_points.set_geometry("center", inplace = True)
gdf
# Out:
# C:\Users\sb\AppData\Local\Temp/ipykernel_22892/3486122233.py:5: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   gdf["center"] = gdf["geometry"].centroid
#                  name                                           geometry  \
# 0               Busan  MULTIPOLYGON (((128.99403 34.98180, 128.99403 ...
# 1   Chungcheongbuk-do  POLYGON ((128.01720 36.20695, 128.01471 36.199...
# 2   Chungcheongnam-do  MULTIPOLYGON (((126.61459 36.06736, 126.61459 ...
# 3               Daegu  POLYGON ((128.68794 35.68165, 128.67543 35.671...
# 4             Daejeon  POLYGON ((127.38995 36.20081, 127.38162 36.204...
# 5          Gangwon-do  MULTIPOLYGON (((129.32625 37.28597, 129.32625 ...
# 6             Gwangju  POLYGON ((127.01669 35.10629, 127.01091 35.094...
# 7         Gyeonggi-do  MULTIPOLYGON (((126.72736 37.01403, 126.72736 ...
# 8    Gyeongsangbuk-do  MULTIPOLYGON (((129.42291 36.01875, 129.42291 ...
# 9    Gyeongsangnam-do  MULTIPOLYGON (((128.73097 34.53931, 128.73097 ...
# 10            Incheon  MULTIPOLYGON (((129.03375 35.08601, 129.03375 ...
# 11               Jeju  MULTIPOLYGON (((126.26930 33.12486, 126.26930 ...
# 12       Jeollabuk-do  MULTIPOLYGON (((126.23402 35.58625, 126.23402 ...
# 13       Jeollanam-do  MULTIPOLYGON (((126.35736 33.73069, 126.35736 ...
# 14             Sejong  POLYGON ((127.26335 36.39206, 127.26129 36.400...
# 15              Seoul  POLYGON ((126.91203 37.43707, 126.90575 37.437...
# 16              Ulsan  MULTIPOLYGON (((129.35153 35.38708, 129.35153 ...
#
#                         center
# 0   POINT (129.08145 35.20247)
# 1   POINT (127.81822 36.70061)
# 2   POINT (126.83102 36.52537)
# 3   POINT (128.57993 35.78117)
# 4   POINT (127.37859 36.31868)
# 5   POINT (128.28101 37.71683)
# 6   POINT (126.85513 35.13442)
# 7   POINT (127.18552 37.49071)
# 8   POINT (128.74910 36.31438)
# 9   POINT (128.27773 35.29987)
# 10  POINT (126.49150 37.54266)
# 11  POINT (126.55505 33.38452)
# 12  POINT (127.15520 35.69783)
# 13  POINT (126.90136 34.86772)
# 14  POINT (127.23920 36.54758)
# 15  POINT (126.99095 37.53330)
# 16  POINT (129.24149 35.53641)

# %%
# 시도경계 지도화
gdf.plot(figsize=(32,16))
# Out:
# <AxesSubplot:>

# %%
avg = pd.read_csv('avg_insurance.csv', index_col=0)
avg
# Out:
#    시군구별  평균보험료(원)
# 0    서울    128688
# 1    부산    104762
# 2    대구    115111
# 3    인천    100195
# 4    광주    109852
# 5    대전    110355
# 6    울산    131744
# 7    세종    107897
# 8    경기    108340
# 9    강원    112611
# 10   충북    127103
# 11   충남    106567
# 12   전북    111213
# 13   전남    109878
# 14   경북    102965
# 15   경남    108135
# 16   제주     99280

# %%
avg['시군구별'] = ['Seoul', 'Busan', 'Daegu', 'Incheon', 'Gwangju', 'Daejeon', 'Ulsan',
                           'Sejong', 'Gyeonggi-do', 'Gangwon-do', 'Chungcheongbuk-do',
                           'Chungcheongnam-do', 'Jeollabuk-do', 'Jeollanam-do', 'Gyeongsangbuk-do',
                           'Gyeongsangnam-do', 'Jeju']

# %%
avg
# Out:
#                  시군구별  평균보험료(원)
# 0               Seoul    128688
# 1               Busan    104762
# 2               Daegu    115111
# 3             Incheon    100195
# 4             Gwangju    109852
# 5             Daejeon    110355
# 6               Ulsan    131744
# 7              Sejong    107897
# 8         Gyeonggi-do    108340
# 9          Gangwon-do    112611
# 10  Chungcheongbuk-do    127103
# 11  Chungcheongnam-do    106567
# 12       Jeollabuk-do    111213
# 13       Jeollanam-do    109878
# 14   Gyeongsangbuk-do    102965
# 15   Gyeongsangnam-do    108135
# 16               Jeju     99280

# %%
#avg.drop(avg.columns[0], axis=1, inplace=True)

# %%
#avg

# %%
#avg = avg[['시도별', '평균보험료(원)']]

# %%
avg.rename(columns={'시군구별':'name'}, inplace=True)

# %%
avg
# Out:
#                  name  평균보험료(원)
# 0               Seoul    128688
# 1               Busan    104762
# 2               Daegu    115111
# 3             Incheon    100195
# 4             Gwangju    109852
# 5             Daejeon    110355
# 6               Ulsan    131744
# 7              Sejong    107897
# 8         Gyeonggi-do    108340
# 9          Gangwon-do    112611
# 10  Chungcheongbuk-do    127103
# 11  Chungcheongnam-do    106567
# 12       Jeollabuk-do    111213
# 13       Jeollanam-do    109878
# 14   Gyeongsangbuk-do    102965
# 15   Gyeongsangnam-do    108135
# 16               Jeju     99280

# %%
# Geopandas 병합
gdf = pd.merge(gdf, avg, on='name')
gdf
# Out:
#                  name                                           geometry  \
# 0               Busan  MULTIPOLYGON (((128.99403 34.98180, 128.99403 ...
# 1   Chungcheongbuk-do  POLYGON ((128.01720 36.20695, 128.01471 36.199...
# 2   Chungcheongnam-do  MULTIPOLYGON (((126.61459 36.06736, 126.61459 ...
# 3               Daegu  POLYGON ((128.68794 35.68165, 128.67543 35.671...
# 4             Daejeon  POLYGON ((127.38995 36.20081, 127.38162 36.204...
# 5          Gangwon-do  MULTIPOLYGON (((129.32625 37.28597, 129.32625 ...
# 6             Gwangju  POLYGON ((127.01669 35.10629, 127.01091 35.094...
# 7         Gyeonggi-do  MULTIPOLYGON (((126.72736 37.01403, 126.72736 ...
# 8    Gyeongsangbuk-do  MULTIPOLYGON (((129.42291 36.01875, 129.42291 ...
# 9    Gyeongsangnam-do  MULTIPOLYGON (((128.73097 34.53931, 128.73097 ...
# 10            Incheon  MULTIPOLYGON (((129.03375 35.08601, 129.03375 ...
# 11               Jeju  MULTIPOLYGON (((126.26930 33.12486, 126.26930 ...
# 12       Jeollabuk-do  MULTIPOLYGON (((126.23402 35.58625, 126.23402 ...
# 13       Jeollanam-do  MULTIPOLYGON (((126.35736 33.73069, 126.35736 ...
# 14             Sejong  POLYGON ((127.26335 36.39206, 127.26129 36.400...
# 15              Seoul  POLYGON ((126.91203 37.43707, 126.90575 37.437...
# 16              Ulsan  MULTIPOLYGON (((129.35153 35.38708, 129.35153 ...
#
#                         center  평균보험료(원)
# 0   POINT (129.08145 35.20247)    104762
# 1   POINT (127.81822 36.70061)    127103
# 2   POINT (126.83102 36.52537)    106567
# 3   POINT (128.57993 35.78117)    115111
# 4   POINT (127.37859 36.31868)    110355
# 5   POINT (128.28101 37.71683)    112611
# 6   POINT (126.85513 35.13442)    109852
# 7   POINT (127.18552 37.49071)    108340
# 8   POINT (128.74910 36.31438)    102965
# 9   POINT (128.27773 35.29987)    108135
# 10  POINT (126.49150 37.54266)    100195
# 11  POINT (126.55505 33.38452)     99280
# 12  POINT (127.15520 35.69783)    111213
# 13  POINT (126.90136 34.86772)    109878
# 14  POINT (127.23920 36.54758)    107897
# 15  POINT (126.99095 37.53330)    128688
# 16  POINT (129.24149 35.53641)    131744

# %%
f, ax = plt.subplots(1, 1, figsize=(16,8))
gdf.plot(column='평균보험료(원)', ax=ax,
                legend=True, legend_kwds={'loc':'lower right'},
                cmap='YlOrBr', scheme='quantiles')
plt.rc('font', family='Malgun Gothic')
texts = []
for x, y, label in zip(gdf_points.geometry.x, gdf_points.geometry.y, gdf_points['city']):
    texts.append(plt.text(x, y, label, fontsize = 10))
texts
# Out:
# [Text(129.08144553202422, 35.202467120818206, '부산'),
#  Text(127.8182155436063, 36.70060634031383, '충북'),
#  Text(126.83101720956076, 36.52536973315283, '충남'),
#  Text(128.57992603155574, 35.78116615939339, '대구'),
#  Text(127.37859450612459, 36.31868326017745, '대전'),
#  Text(128.28100983831516, 37.7168307841873, '강원'),
#  Text(126.8551262303894, 35.13442287062025, '광주'),
#  Text(127.18552322796268, 37.490708272884184, '경기'),
#  Text(128.7491013241077, 36.31438099314429, '경북'),
#  Text(128.27773388994544, 35.2998670396828, '경남'),
#  Text(126.49149965618524, 37.542659333049365, '인천'),
#  Text(126.55504506695989, 33.38452107018577, '제주'),
#  Text(127.1552043519384, 35.69782635068909, '전북'),
#  Text(126.90135587019878, 34.86772411956629, '전남'),
#  Text(127.23919705550556, 36.547582009517335, '세종'),
#  Text(126.99095441063136, 37.53329786891548, '서울'),
#  Text(129.24149211156725, 35.53641488697799, '울산')]
