# %%
import geopandas as gpd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable
from shapely.geometry import Point

# %%
# 시도경계 shapefile
shapefile = 'C:\DataScience\project\geo_data\gadm36_KOR_1.shp'
gdf = gpd.read_file(shapefile)[['NAME_1', 'geometry']]
gdf.columns = ['name','geometry']
gdf
gdf["center"] = gdf["geometry"].centroid
gdf_points = gdf.copy()
gdf_points['city']=['부산', '충북','충남','대구','대전','강원','광주','경기','경북',
                    '경남','인천','제주','전북','전남','세종','서울','울산']
gdf_points.set_geometry("center", inplace = True)
# Out:
# C:\Users\LGGRAM~1\AppData\Local\Temp/ipykernel_25572/2588617446.py:6: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   gdf["center"] = gdf["geometry"].centroid

# %%
gdf.to_csv('../koreamap.csv')

# %%
gdf_points
# Out:
#                  name                                           geometry  \
# 0               Busan  MULTIPOLYGON (((128.99403 34.98180, 128.99403 ...
# 1   Chungcheongbuk-do  POLYGON ((128.01720 36.20695, 128.01471 36.199...
# 2   Chungcheongnam-do  MULTIPOLYGON (((126.61459 36.06736, 126.61459 ...
# 3               Daegu  POLYGON ((128.68794 35.68165, 128.67543 35.671...
# 4             Daejeon  POLYGON ((127.38995 36.20081, 127.38162 36.204...
# 5          Gangwon-do  MULTIPOLYGON (((129.32625 37.28597, 129.32625 ...
# 6             Gwangju  POLYGON ((127.01669 35.10629, 127.01091 35.094...
# 7         Gyeonggi-do  MULTIPOLYGON (((126.72736 37.01403, 126.72736 ...
# 8    Gyeongsangbuk-do  MULTIPOLYGON (((129.42291 36.01875, 129.42291 ...
# 9    Gyeongsangnam-do  MULTIPOLYGON (((128.73097 34.53931, 128.73097 ...
# 10            Incheon  MULTIPOLYGON (((129.03375 35.08601, 129.03375 ...
# 11               Jeju  MULTIPOLYGON (((126.26930 33.12486, 126.26930 ...
# 12       Jeollabuk-do  MULTIPOLYGON (((126.23402 35.58625, 126.23402 ...
# 13       Jeollanam-do  MULTIPOLYGON (((126.35736 33.73069, 126.35736 ...
# 14             Sejong  POLYGON ((127.26335 36.39206, 127.26129 36.400...
# 15              Seoul  POLYGON ((126.91203 37.43707, 126.90575 37.437...
# 16              Ulsan  MULTIPOLYGON (((129.35153 35.38708, 129.35153 ...
#
#                         center city
# 0   POINT (129.08145 35.20247)   부산
# 1   POINT (127.81822 36.70061)   충북
# 2   POINT (126.83102 36.52537)   충남
# 3   POINT (128.57993 35.78117)   대구
# 4   POINT (127.37859 36.31868)   대전
# 5   POINT (128.28101 37.71683)   강원
# 6   POINT (126.85513 35.13442)   광주
# 7   POINT (127.18552 37.49071)   경기
# 8   POINT (128.74910 36.31438)   경북
# 9   POINT (128.27773 35.29987)   경남
# 10  POINT (126.49150 37.54266)   인천
# 11  POINT (126.55505 33.38452)   제주
# 12  POINT (127.15520 35.69783)   전북
# 13  POINT (126.90136 34.86772)   전남
# 14  POINT (127.23920 36.54758)   세종
# 15  POINT (126.99095 37.53330)   서울
# 16  POINT (129.24149 35.53641)   울산

# %%
# 시도경계 지도화
gdf.plot(figsize=(16,8))
# Out:
# <AxesSubplot:>

# %%
ratio_blue = pd.read_csv('../../data/연령별 수검자대비 우울증비율.csv', index_col=0)

# %%
ratio_blue
# Out:
#    시도별   30세우울비율   40세우울비율   50세우울비율
# 1   서울  8.553874  6.838839  5.180332
# 2   부산  6.934196  5.150765  4.122612
# 3   대구  6.344078  5.411921  3.980486
# 4   인천  7.844461  6.486968  5.062270
# 5   광주  6.489676  4.604735  3.650523
# 6   대전  7.830829  6.293751  4.917664
# 7   울산  6.286963  4.800591  3.744876
# 8   세종  5.488686  5.963567  4.753255
# 9   경기  7.665712  6.513172  5.113291
# 10  강원  6.851293  5.589124  4.070851
# 11  충북  7.396783  5.832429  4.276244
# 12  충남  7.390889  5.901070  4.485896
# 13  전북  6.285924  4.461432  3.595863
# 14  전남  4.952947  4.170873  3.453502
# 15  경북  6.499508  5.335030  3.722542
# 16  경남  5.781232  4.873959  4.017927
# 17  제주  9.019731  6.413690  4.675096

# %%
ratio_blue['시도별'] = ['Seoul', 'Busan', 'Daegu', 'Incheon', 'Gwangju', 'Daejeon', 'Ulsan',
                           'Sejong', 'Gyeonggi-do', 'Gangwon-do', 'Chungcheongbuk-do',
                           'Chungcheongnam-do', 'Jeollabuk-do', 'Jeollanam-do', 'Gyeongsangbuk-do',
                           'Gyeongsangnam-do', 'Jeju']

# %%
ratio_blue.rename(columns={'시도별':'name'}, inplace=True)

# %%
ratio_blue
# Out:
#                  name   30세우울비율   40세우울비율   50세우울비율
# 1               Seoul  8.553874  6.838839  5.180332
# 2               Busan  6.934196  5.150765  4.122612
# 3               Daegu  6.344078  5.411921  3.980486
# 4             Incheon  7.844461  6.486968  5.062270
# 5             Gwangju  6.489676  4.604735  3.650523
# 6             Daejeon  7.830829  6.293751  4.917664
# 7               Ulsan  6.286963  4.800591  3.744876
# 8              Sejong  5.488686  5.963567  4.753255
# 9         Gyeonggi-do  7.665712  6.513172  5.113291
# 10         Gangwon-do  6.851293  5.589124  4.070851
# 11  Chungcheongbuk-do  7.396783  5.832429  4.276244
# 12  Chungcheongnam-do  7.390889  5.901070  4.485896
# 13       Jeollabuk-do  6.285924  4.461432  3.595863
# 14       Jeollanam-do  4.952947  4.170873  3.453502
# 15   Gyeongsangbuk-do  6.499508  5.335030  3.722542
# 16   Gyeongsangnam-do  5.781232  4.873959  4.017927
# 17               Jeju  9.019731  6.413690  4.675096

# %%
ratio_blue.drop(ratio_blue.columns[4], axis=1, inplace=True)

# %%
# Geopandas 병합
gdf = pd.merge(gdf, ratio_blue, on='name')
gdf
# Out:
#                  name                                           geometry  \
# 0               Busan  MULTIPOLYGON (((128.99403 34.98180, 128.99403 ...
# 1   Chungcheongbuk-do  POLYGON ((128.01720 36.20695, 128.01471 36.199...
# 2   Chungcheongnam-do  MULTIPOLYGON (((126.61459 36.06736, 126.61459 ...
# 3               Daegu  POLYGON ((128.68794 35.68165, 128.67543 35.671...
# 4             Daejeon  POLYGON ((127.38995 36.20081, 127.38162 36.204...
# 5          Gangwon-do  MULTIPOLYGON (((129.32625 37.28597, 129.32625 ...
# 6             Gwangju  POLYGON ((127.01669 35.10629, 127.01091 35.094...
# 7         Gyeonggi-do  MULTIPOLYGON (((126.72736 37.01403, 126.72736 ...
# 8    Gyeongsangbuk-do  MULTIPOLYGON (((129.42291 36.01875, 129.42291 ...
# 9    Gyeongsangnam-do  MULTIPOLYGON (((128.73097 34.53931, 128.73097 ...
# 10            Incheon  MULTIPOLYGON (((129.03375 35.08601, 129.03375 ...
# 11               Jeju  MULTIPOLYGON (((126.26930 33.12486, 126.26930 ...
# 12       Jeollabuk-do  MULTIPOLYGON (((126.23402 35.58625, 126.23402 ...
# 13       Jeollanam-do  MULTIPOLYGON (((126.35736 33.73069, 126.35736 ...
# 14             Sejong  POLYGON ((127.26335 36.39206, 127.26129 36.400...
# 15              Seoul  POLYGON ((126.91203 37.43707, 126.90575 37.437...
# 16              Ulsan  MULTIPOLYGON (((129.35153 35.38708, 129.35153 ...
#
#                         center   30세우울비율   40세우울비율   50세우울비율
# 0   POINT (129.08145 35.20247)  6.934196  5.150765  4.122612
# 1   POINT (127.81822 36.70061)  7.396783  5.832429  4.276244
# 2   POINT (126.83102 36.52537)  7.390889  5.901070  4.485896
# 3   POINT (128.57993 35.78117)  6.344078  5.411921  3.980486
# 4   POINT (127.37859 36.31868)  7.830829  6.293751  4.917664
# 5   POINT (128.28101 37.71683)  6.851293  5.589124  4.070851
# 6   POINT (126.85513 35.13442)  6.489676  4.604735  3.650523
# 7   POINT (127.18552 37.49071)  7.665712  6.513172  5.113291
# 8   POINT (128.74910 36.31438)  6.499508  5.335030  3.722542
# 9   POINT (128.27773 35.29987)  5.781232  4.873959  4.017927
# 10  POINT (126.49150 37.54266)  7.844461  6.486968  5.062270
# 11  POINT (126.55505 33.38452)  9.019731  6.413690  4.675096
# 12  POINT (127.15520 35.69783)  6.285924  4.461432  3.595863
# 13  POINT (126.90136 34.86772)  4.952947  4.170873  3.453502
# 14  POINT (127.23920 36.54758)  5.488686  5.963567  4.753255
# 15  POINT (126.99095 37.53330)  8.553874  6.838839  5.180332
# 16  POINT (129.24149 35.53641)  6.286963  4.800591  3.744876

# %%
# 시도별 우울비율 지도화 : 30세
f, ax = plt.subplots(1, 1, figsize=(16,8))
gdf.plot(column='30세우울비율', ax=ax,
                legend=True, legend_kwds={'loc':'lower right'},
                cmap='summer_r', scheme='quantiles')
plt.rc('font', family='Malgun Gothic')
texts = []
for x, y, label in zip(gdf_points.geometry.x, gdf_points.geometry.y, gdf_points['city']):
    texts.append(plt.text(x, y, label, fontsize = 10))
texts
# Out:
# [Text(129.08144553202422, 35.202467120818206, '부산'),
#  Text(127.8182155436063, 36.70060634031383, '충북'),
#  Text(126.83101720956076, 36.52536973315283, '충남'),
#  Text(128.57992603155574, 35.78116615939339, '대구'),
#  Text(127.37859450612459, 36.31868326017745, '대전'),
#  Text(128.28100983831516, 37.7168307841873, '강원'),
#  Text(126.8551262303894, 35.13442287062025, '광주'),
#  Text(127.18552322796268, 37.490708272884184, '경기'),
#  Text(128.7491013241077, 36.31438099314429, '경북'),
#  Text(128.27773388994544, 35.2998670396828, '경남'),
#  Text(126.49149965618524, 37.542659333049365, '인천'),
#  Text(126.55504506695989, 33.38452107018577, '제주'),
#  Text(127.1552043519384, 35.69782635068909, '전북'),
#  Text(126.90135587019878, 34.86772411956629, '전남'),
#  Text(127.23919705550556, 36.547582009517335, '세종'),
#  Text(126.99095441063136, 37.53329786891548, '서울'),
#  Text(129.24149211156725, 35.53641488697799, '울산')]

# %%
# 시도별 우울비율 지도화 : 40세
f, ax = plt.subplots(1, 1, figsize=(16,8))
gdf.plot(column='40세우울비율', ax=ax,
                legend=True, legend_kwds={'loc':'lower right'},
                cmap='autumn_r', scheme='quantiles')
plt.rc('font', family='Malgun Gothic')
texts = []
for x, y, label in zip(gdf_points.geometry.x, gdf_points.geometry.y, gdf_points['city']):
    texts.append(plt.text(x, y, label, fontsize = 10))
texts
# Out:
# [Text(129.08144553202422, 35.202467120818206, '부산'),
#  Text(127.8182155436063, 36.70060634031383, '충북'),
#  Text(126.83101720956076, 36.52536973315283, '충남'),
#  Text(128.57992603155574, 35.78116615939339, '대구'),
#  Text(127.37859450612459, 36.31868326017745, '대전'),
#  Text(128.28100983831516, 37.7168307841873, '강원'),
#  Text(126.8551262303894, 35.13442287062025, '광주'),
#  Text(127.18552322796268, 37.490708272884184, '경기'),
#  Text(128.7491013241077, 36.31438099314429, '경북'),
#  Text(128.27773388994544, 35.2998670396828, '경남'),
#  Text(126.49149965618524, 37.542659333049365, '인천'),
#  Text(126.55504506695989, 33.38452107018577, '제주'),
#  Text(127.1552043519384, 35.69782635068909, '전북'),
#  Text(126.90135587019878, 34.86772411956629, '전남'),
#  Text(127.23919705550556, 36.547582009517335, '세종'),
#  Text(126.99095441063136, 37.53329786891548, '서울'),
#  Text(129.24149211156725, 35.53641488697799, '울산')]

# %%
# 시도별 우울비율 지도화 : 50세
f, ax = plt.subplots(1, 1, figsize=(16,8))
gdf.plot(column='50세우울비율', ax=ax,
                legend=True, legend_kwds={'loc':'lower right'},
                cmap='BuPu', scheme='quantiles')
plt.rc('font', family='Malgun Gothic')
texts = []
for x, y, label in zip(gdf_points.geometry.x, gdf_points.geometry.y, gdf_points['city']):
    texts.append(plt.text(x, y, label, fontsize = 10))
texts
# Out:
# [Text(129.08144553202422, 35.202467120818206, '부산'),
#  Text(127.8182155436063, 36.70060634031383, '충북'),
#  Text(126.83101720956076, 36.52536973315283, '충남'),
#  Text(128.57992603155574, 35.78116615939339, '대구'),
#  Text(127.37859450612459, 36.31868326017745, '대전'),
#  Text(128.28100983831516, 37.7168307841873, '강원'),
#  Text(126.8551262303894, 35.13442287062025, '광주'),
#  Text(127.18552322796268, 37.490708272884184, '경기'),
#  Text(128.7491013241077, 36.31438099314429, '경북'),
#  Text(128.27773388994544, 35.2998670396828, '경남'),
#  Text(126.49149965618524, 37.542659333049365, '인천'),
#  Text(126.55504506695989, 33.38452107018577, '제주'),
#  Text(127.1552043519384, 35.69782635068909, '전북'),
#  Text(126.90135587019878, 34.86772411956629, '전남'),
#  Text(127.23919705550556, 36.547582009517335, '세종'),
#  Text(126.99095441063136, 37.53329786891548, '서울'),
#  Text(129.24149211156725, 35.53641488697799, '울산')]
