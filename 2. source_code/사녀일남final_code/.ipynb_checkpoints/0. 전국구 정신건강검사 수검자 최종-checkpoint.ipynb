# %%
import pandas as pd
import numpy as np

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity="all"

# %%
blue = pd.read_csv('../data/raw/시도별_연령별_일반건강검진_정신건강검사_결과__기분상태_및_우울증__20210814205240.csv', encoding='euc-kr')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-1ed153676e5a> in <module>
# ----> 1 blue = pd.read_csv('../data/raw/시도별_연령별_일반건강검진_정신건강검사_결과__기분상태_및_우울증__20210814205240.csv', encoding='euc-kr')
#
# ...

# %%
blue
# Out:
#     시도별(1)  성별(1)     2019       2019.1     2019.2  2019.3       2019.4  \
# 0   시도별(1)  성별(1)        계            계          계     30세          30세
# 1   시도별(1)  성별(1)        계  중간정도 우울증 의심  심한 우울증 의심       계  중간정도 우울증 의심
# 2        계     합계  2347074       110014      10980  317830        21918
# 3       서울     합계   436527        23406       2464   73078         5761
# 4       부산     합계   158217         6618        585   19786         1289
# 5       대구     합계   110716         4440        405   13619          801
# 6       인천     합계   137808         7198        637   19262         1398
# 7       광주     합계    67597         2602        301    8136          489
# 8       대전     합계    70151         3572        302    9718          711
# 9       울산     합계    55870         2289        181    7778          463
# 10      세종     합계    14849          707         80    2077          100
# 11      경기     합계   596132        31445       2846   84167         6022
# ...

# %%
blue.drop(blue.index[0], inplace=True)
del blue['2019.1']
del blue['2019.2']
del blue['2019']
del blue['성별(1)']
blue
# Out:
#     시도별(1)  2019.3       2019.4     2019.5  2019.6       2019.7     2019.8  \
# 1   시도별(1)       계  중간정도 우울증 의심  심한 우울증 의심       계  중간정도 우울증 의심  심한 우울증 의심
# 2        계  317830        21918       1675  531306        29176       2475
# 3       서울   73078         5761        490   97151         6060        584
# 4       부산   19786         1289         83   34325         1641        127
# 5       대구   13619          801         63   24058         1197        105
# 6       인천   19262         1398        113   32573         1954        159
# 7       광주    8136          489         39   16179          676         69
# 8       대전    9718          711         50   15571          910         70
# 9       울산    7778          463         26   13540          606         44
# 10      세종    2077          100         14    5215          288         23
# 11      경기   84167         6022        430  145152         8802        652
# ...

# %%
blue.columns=['시도별', '30세 수검자합계', '30중간정도 우울증 의심', '30심한 우울증 의심',
             '40세 수검자합계', '40중간정도 우울증 의심', '40심한 우울증 의심',
             '50세 수검자합계', '50중간정도 우울증 의심', '50심한 우울증 의심']

# %%
blue
# Out:
#        시도별 30세 수검자합계 30중간정도 우울증 의심 30심한 우울증 의심 40세 수검자합계 40중간정도 우울증 의심  \
# 1   시도별(1)         계   중간정도 우울증 의심   심한 우울증 의심         계   중간정도 우울증 의심
# 2        계    317830         21918        1675    531306         29176
# 3       서울     73078          5761         490     97151          6060
# 4       부산     19786          1289          83     34325          1641
# 5       대구     13619           801          63     24058          1197
# 6       인천     19262          1398         113     32573          1954
# 7       광주      8136           489          39     16179           676
# 8       대전      9718           711          50     15571           910
# 9       울산      7778           463          26     13540           606
# 10      세종      2077           100          14      5215           288
# 11      경기     84167          6022         430    145152          8802
# 12      강원      7619           478          44     13240           688
# ...

# %%
# blue = blue.drop([blue.index[0], blue.index[1]])
blue.index = (range(1,len(blue)+1))
blue
# Out:
#    시도별 30세 수검자합계 30중간정도 우울증 의심 30심한 우울증 의심 40세 수검자합계 40중간정도 우울증 의심  \
# 1   서울     73078          5761         490     97151          6060
# 2   부산     19786          1289          83     34325          1641
# 3   대구     13619           801          63     24058          1197
# 4   인천     19262          1398         113     32573          1954
# 5   광주      8136           489          39     16179           676
# 6   대전      9718           711          50     15571           910
# 7   울산      7778           463          26     13540           606
# 8   세종      2077           100          14      5215           288
# 9   경기     84167          6022         430    145152          8802
# 10  강원      7619           478          44     13240           688
# 11  충북      9761           678          44     15671           854
# 12  충남     12556           865          63     20742          1140
# 13  전북      8177           479          35     15959           657
# ...

# %%
del blue['30세우울']
del blue['40세우울']
del blue['50세우울']

# %%
blue['30세우울']=blue['30중간정도 우울증 의심']+blue['30심한 우울증 의심']
blue['40세우울']=blue['40중간정도 우울증 의심']+blue['40심한 우울증 의심']
blue['50세우울']=blue['50중간정도 우울증 의심']+blue['50심한 우울증 의심']

# %%
# blue.drop(blue.columns[2:4], axis=1, inplace=True)
#blue.drop(blue.columns[3:5], axis=1, inplace=True)
# blue.drop(blue.columns[4:6], axis=1, inplace=True)

blue = blue.reindex(columns=['시도별','30세 수검자합계', '30세우울', '40세 수검자합계', '40세우울', '50세 수검자합계','50세우울'])
blue
# Out:
#    시도별  30세 수검자합계  30세우울  40세 수검자합계  40세우울  50세 수검자합계  50세우울
# 1   서울      73078   6251      97151   6644      97986   5076
# 2   부산      19786   1372      34325   1768      34711   1431
# 3   대구      13619    864      24058   1302      27057   1077
# 4   인천      19262   1511      32573   2113      33483   1695
# 5   광주       8136    528      16179    745      16436    600
# 6   대전       9718    761      15571    980      17793    875
# 7   울산       7778    489      13540    650      14393    539
# 8   세종       2077    114       5215    311       3303    157
# 9   경기      84167   6452     145152   9454     151292   7736
# 10  강원       7619    522      13240    740      16090    655
# 11  충북       9761    722      15671    914      18404    787
# 12  충남      12556    928      20742   1224      21980    986
# 13  전북       8177    514      15959    712      18855    678
# 14  전남       8076    400      15848    661      18474    638
# ...

# %%
df = pd.read_csv('../data/전국구 정신건강검사 수검자 최종.csv', index_col=0)
df
# Out:
#    시도별  30세 수검자합계  30세우울  40세 수검자합계  40세우울  50세 수검자합계  50세우울
# 1   서울      73078   6251      97151   6644      97986   5076
# 2   부산      19786   1372      34325   1768      34711   1431
# 3   대구      13619    864      24058   1302      27057   1077
# 4   인천      19262   1511      32573   2113      33483   1695
# 5   광주       8136    528      16179    745      16436    600
# 6   대전       9718    761      15571    980      17793    875
# 7   울산       7778    489      13540    650      14393    539
# 8   세종       2077    114       5215    311       3303    157
# 9   경기      84167   6452     145152   9454     151292   7736
# 10  강원       7619    522      13240    740      16090    655
# 11  충북       9761    722      15671    914      18404    787
# 12  충남      12556    928      20742   1224      21980    986
# 13  전북       8177    514      15959    712      18855    678
# 14  전남       8076    400      15848    661      18474    638
# ...

# %%
df.rename(columns={'30세우울':'30세우울(명)', '40세우울':'40세우울(명)', '50세우울':'50세우울(명)'})
# Out:
#    시도별  30세 수검자합계  30세우울(명)  40세 수검자합계  40세우울(명)  50세 수검자합계  50세우울(명)
# 1   서울      73078      6251      97151      6644      97986      5076
# 2   부산      19786      1372      34325      1768      34711      1431
# 3   대구      13619       864      24058      1302      27057      1077
# 4   인천      19262      1511      32573      2113      33483      1695
# 5   광주       8136       528      16179       745      16436       600
# 6   대전       9718       761      15571       980      17793       875
# 7   울산       7778       489      13540       650      14393       539
# 8   세종       2077       114       5215       311       3303       157
# 9   경기      84167      6452     145152      9454     151292      7736
# 10  강원       7619       522      13240       740      16090       655
# 11  충북       9761       722      15671       914      18404       787
# 12  충남      12556       928      20742      1224      21980       986
# ...

# %%
df.to_csv('../data/전국구 정신건강검사 수검자 최종.csv')
